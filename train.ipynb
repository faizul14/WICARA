# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

DATA_PATH = "/content/drive/MyDrive/Capstone/json/dataminang.json"
SAVED_MODEL_PATH = "/content/drive/MyDrive/Capstone/Model/model_minang.h5"
EPOCHS = 50
BATCH_SIZE = 32
PATIENCE = 5
LEARNING_RATE = 0.0001


def load_data(data_path):
    """Loads training dataset from json file.
    :param data_path (str): Path to json file containing data
    :return X (ndarray): Inputs
    :return y (ndarray): Targets
    """
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["MFCCs"])
    y = np.array(data["labels"])
    print("Training sets loaded!")
    return X, y


def prepare_dataset(data_path, test_size=0.2, validation_size=0.2):
    """Creates train, validation and test sets.
    :param data_path (str): Path to json file containing data
    :param test_size (flaot): Percentage of dataset used for testing
    :param validation_size (float): Percentage of train set used for cross-validation
    :return X_train (ndarray): Inputs for the train set
    :return y_train (ndarray): Targets for the train set
    :return X_validation (ndarray): Inputs for the validation set
    :return y_validation (ndarray): Targets for the validation set
    :return X_test (ndarray): Inputs for the test set
    :return X_test (ndarray): Targets for the test set
    """

    # load dataset
    X, y = load_data(data_path)

    # create train, validation, test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to nd array
    X_train = X_train[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]

    return X_train, y_train, X_validation, y_validation, X_test, y_test


def build_model(input_shape, loss="sparse_categorical_crossentropy", learning_rate=0.0001):
    """Build neural network using keras.
    :param input_shape (tuple): Shape of array representing a sample train. E.g.: (44, 13, 1)
    :param loss (str): Loss function to use
    :param learning_rate (float):
    :return model: TensorFlow model
    """

    # build network architecture using convolutional layers
    model = tf.keras.models.Sequential()

    # 1st conv layer
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape,
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 2nd conv layer
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 3rd conv layer
    model.add(tf.keras.layers.Conv2D(32, (2, 2), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2), padding='same'))

    # flatten output and feed into dense layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    tf.keras.layers.Dropout(0.3)

    # softmax output layer
    model.add(tf.keras.layers.Dense(20, activation='softmax'))

    optimiser = tf.optimizers.Adam(learning_rate=learning_rate)

    # compile model
    model.compile(optimizer=optimiser,
                  loss=loss,
                  metrics=["accuracy"])

    # print model parameters on console
    model.summary()

    return model


def train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation):
    """Trains model
    :param epochs (int): Num training epochs
    :param batch_size (int): Samples per batch
    :param patience (int): Num epochs to wait before early stop, if there isn't an improvement on accuracy
    :param X_train (ndarray): Inputs for the train set
    :param y_train (ndarray): Targets for the train set
    :param X_validation (ndarray): Inputs for the validation set
    :param y_validation (ndarray): Targets for the validation set
    :return history: Training history
    """

    earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=patience)

    # train model
    history = model.fit(X_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_validation, y_validation),
                        callbacks=[earlystop_callback])
    return history


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
    :param history: Training history of model
    :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="accuracy")
    axs[0].plot(history.history['val_accuracy'], label="val_accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy evaluation")

    # create loss subplot
    axs[1].plot(history.history["loss"], label="loss")
    axs[1].plot(history.history['val_loss'], label="val_loss")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Loss")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Loss evaluation")

    plt.show()


def main():
    # generate train, validation and test sets
    X_train, y_train, X_validation, y_validation, X_test, y_test = prepare_dataset(DATA_PATH)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape, learning_rate=LEARNING_RATE)

    # train network
    history = train(model, EPOCHS, BATCH_SIZE, PATIENCE, X_train, y_train, X_validation, y_validation)

    # plot accuracy/loss for training/validation set as a function of the epochs
    plot_history(history)

    # evaluate network on test set
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print("\nTest loss: {}, test accuracy: {}".format(test_loss, 100*test_acc))

    # save model
    model.save(SAVED_MODEL_PATH)


if __name__ == "__main__":
    main()
# Out:
# Training sets loaded!
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 42, 11, 64)        640
#
#  batch_normalization_24 (Bat  (None, 42, 11, 64)       256
#  chNormalization)
#
#  max_pooling2d_24 (MaxPoolin  (None, 21, 6, 64)        0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 19, 4, 32)         18464
#
#  batch_normalization_25 (Bat  (None, 19, 4, 32)        128
#  chNormalization)
#
#  max_pooling2d_25 (MaxPoolin  (None, 10, 2, 32)        0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 9, 1, 32)          4128
#
#  batch_normalization_26 (Bat  (None, 9, 1, 32)         128
#  chNormalization)
#
#  max_pooling2d_26 (MaxPoolin  (None, 5, 1, 32)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 160)               0
#
#  dense_16 (Dense)            (None, 64)                10304
#
#  dense_17 (Dense)            (None, 20)                1300
#
# =================================================================
# Total params: 35,348
# Trainable params: 35,092
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/50
# 32/32 [==============================] - 3s 64ms/step - loss: 3.2401 - accuracy: 0.0713 - val_loss: 3.1913 - val_accuracy: 0.0977
# Epoch 2/50
# 32/32 [==============================] - 2s 50ms/step - loss: 2.7593 - accuracy: 0.1416 - val_loss: 2.8945 - val_accuracy: 0.1406
# Epoch 3/50
# 32/32 [==============================] - 2s 50ms/step - loss: 2.4438 - accuracy: 0.2832 - val_loss: 2.7545 - val_accuracy: 0.1875
# Epoch 4/50
# 32/32 [==============================] - 2s 49ms/step - loss: 2.2064 - accuracy: 0.3867 - val_loss: 2.6299 - val_accuracy: 0.2148
# Epoch 5/50
# 32/32 [==============================] - 2s 49ms/step - loss: 1.9980 - accuracy: 0.5049 - val_loss: 2.5023 - val_accuracy: 0.2578
# Epoch 6/50
# 32/32 [==============================] - 2s 49ms/step - loss: 1.8341 - accuracy: 0.5625 - val_loss: 2.3655 - val_accuracy: 0.3320
# Epoch 7/50
# 32/32 [==============================] - 2s 55ms/step - loss: 1.6728 - accuracy: 0.6484 - val_loss: 2.1867 - val_accuracy: 0.4375
# Epoch 8/50
# 32/32 [==============================] - 2s 49ms/step - loss: 1.5143 - accuracy: 0.7178 - val_loss: 2.0284 - val_accuracy: 0.5000
# Epoch 9/50
# 32/32 [==============================] - 2s 50ms/step - loss: 1.3858 - accuracy: 0.7705 - val_loss: 1.8890 - val_accuracy: 0.5195
# Epoch 10/50
# 32/32 [==============================] - 3s 97ms/step - loss: 1.2728 - accuracy: 0.7930 - val_loss: 1.7193 - val_accuracy: 0.6211
# Epoch 11/50
# 32/32 [==============================] - 2s 58ms/step - loss: 1.1831 - accuracy: 0.8252 - val_loss: 1.6108 - val_accuracy: 0.6484
# Epoch 12/50
# 32/32 [==============================] - 2s 54ms/step - loss: 1.0666 - accuracy: 0.8604 - val_loss: 1.4637 - val_accuracy: 0.7422
# Epoch 13/50
# 32/32 [==============================] - 2s 50ms/step - loss: 0.9861 - accuracy: 0.8760 - val_loss: 1.3268 - val_accuracy: 0.7500
# Epoch 14/50
# 32/32 [==============================] - 2s 54ms/step - loss: 0.8967 - accuracy: 0.9004 - val_loss: 1.2069 - val_accuracy: 0.8008
# Epoch 15/50
# 32/32 [==============================] - 2s 57ms/step - loss: 0.8256 - accuracy: 0.9121 - val_loss: 1.1073 - val_accuracy: 0.8320
# Epoch 16/50
# 32/32 [==============================] - 2s 56ms/step - loss: 0.7663 - accuracy: 0.9238 - val_loss: 1.0182 - val_accuracy: 0.8320
# Epoch 17/50
# 32/32 [==============================] - 2s 49ms/step - loss: 0.6899 - accuracy: 0.9268 - val_loss: 0.9316 - val_accuracy: 0.8516
# Epoch 18/50
# 32/32 [==============================] - 2s 50ms/step - loss: 0.6441 - accuracy: 0.9346 - val_loss: 0.8767 - val_accuracy: 0.8711
# Epoch 19/50
# 32/32 [==============================] - 3s 86ms/step - loss: 0.5938 - accuracy: 0.9385 - val_loss: 0.8019 - val_accuracy: 0.8945
# Epoch 20/50
# 32/32 [==============================] - 2s 71ms/step - loss: 0.5612 - accuracy: 0.9443 - val_loss: 0.7403 - val_accuracy: 0.8828
# Epoch 21/50
# 32/32 [==============================] - 2s 50ms/step - loss: 0.5073 - accuracy: 0.9561 - val_loss: 0.6819 - val_accuracy: 0.8945
# Epoch 22/50
# 32/32 [==============================] - 2s 57ms/step - loss: 0.4764 - accuracy: 0.9580 - val_loss: 0.6464 - val_accuracy: 0.8906
# Epoch 23/50
# 32/32 [==============================] - 2s 55ms/step - loss: 0.4495 - accuracy: 0.9590 - val_loss: 0.5780 - val_accuracy: 0.9180
# Epoch 24/50
# 32/32 [==============================] - 2s 56ms/step - loss: 0.4115 - accuracy: 0.9609 - val_loss: 0.5392 - val_accuracy: 0.9219
# Epoch 25/50
# 32/32 [==============================] - 2s 52ms/step - loss: 0.3887 - accuracy: 0.9697 - val_loss: 0.5101 - val_accuracy: 0.9180
# Epoch 26/50
# 32/32 [==============================] - 2s 50ms/step - loss: 0.3730 - accuracy: 0.9648 - val_loss: 0.4737 - val_accuracy: 0.9219
# Epoch 27/50
# 32/32 [==============================] - 2s 50ms/step - loss: 0.3469 - accuracy: 0.9678 - val_loss: 0.4527 - val_accuracy: 0.9297
# Epoch 28/50
# 32/32 [==============================] - 2s 57ms/step - loss: 0.3288 - accuracy: 0.9668 - val_loss: 0.4205 - val_accuracy: 0.9258
# Epoch 29/50
# 32/32 [==============================] - 2s 53ms/step - loss: 0.3124 - accuracy: 0.9688 - val_loss: 0.4002 - val_accuracy: 0.9219
# Epoch 30/50
# 32/32 [==============================] - 2s 49ms/step - loss: 0.2975 - accuracy: 0.9717 - val_loss: 0.3847 - val_accuracy: 0.9258
# Epoch 31/50
# 32/32 [==============================] - 2s 49ms/step - loss: 0.2854 - accuracy: 0.9746 - val_loss: 0.3724 - val_accuracy: 0.9297
# Epoch 32/50
# 32/32 [==============================] - 2s 49ms/step - loss: 0.2752 - accuracy: 0.9736 - val_loss: 0.3600 - val_accuracy: 0.9297
# Epoch 33/50
# 32/32 [==============================] - 2s 48ms/step - loss: 0.2683 - accuracy: 0.9775 - val_loss: 0.3404 - val_accuracy: 0.9297
# Epoch 34/50
# 32/32 [==============================] - 2s 50ms/step - loss: 0.2510 - accuracy: 0.9707 - val_loss: 0.3201 - val_accuracy: 0.9297
# Epoch 35/50
# 32/32 [==============================] - 2s 49ms/step - loss: 0.2350 - accuracy: 0.9717 - val_loss: 0.3138 - val_accuracy: 0.9297
# Epoch 36/50
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2354 - accuracy: 0.9775 - val_loss: 0.3055 - val_accuracy: 0.9336
# Epoch 37/50
# 32/32 [==============================] - 2s 56ms/step - loss: 0.2275 - accuracy: 0.9746 - val_loss: 0.2997 - val_accuracy: 0.9297
# Epoch 38/50
# 32/32 [==============================] - 2s 51ms/step - loss: 0.2181 - accuracy: 0.9736 - val_loss: 0.2846 - val_accuracy: 0.9258
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2525 - accuracy: 0.9563
#
# Test loss: 0.25247621536254883, test accuracy: 95.6250011920929
